# %%
import tensorflow as tf
import numpy as np
from PIL import Image

# %%
filename = 'imagenes//perro1.jpg'

# %%
from IPython.display import Image
Image(filename = 'imagenes//perro1.jpg',width =224, height=224 )

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
import cv2

# %%
imgg = cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis =0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions= mobile.predict(final_image)

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
result = imagenet_utils.decode_predictions(predictions)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 3us/step

# %%
print(result)
# Out:
# [[('n02099712', 'Labrador_retriever', 0.6239332), ('n02099601', 'golden_retriever', 0.2939953), ('n02101388', 'Brittany_spaniel', 0.012512281), ('n02101556', 'clumber', 0.001882872), ('n04409515', 'tennis_ball', 0.0017433484)]]
